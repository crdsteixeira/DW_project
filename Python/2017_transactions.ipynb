# %%
import pandas as pd
# set pandas display options to show all columns
pd.set_option('display.max_columns', None)

# %%
transactions = pd.read_csv('DataCoSupplyChainDataset.csv', encoding='iso-8859-1')
metadata = pd.read_csv('DescriptionDataCoSupplyChain.csv')

# %%
transactions["shipping date (DateOrders)"] = pd.to_datetime(transactions["shipping date (DateOrders)"])

# %%
transactions_2017 = transactions[(transactions["shipping date (DateOrders)"] > '2017-01-01 00:00:00') & (transactions["shipping date (DateOrders)"] < '2018-01-01 00:00:00')]
transactions_2017 = transactions_2017.sort_values('shipping date (DateOrders)')
transactions_2017
# Out:
#            Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 37971   PAYMENT                         2                              2
# 111389  PAYMENT                         2                              2
# 150409    DEBIT                         5                              4
# 90435   PAYMENT                         4                              4
# 145800  PAYMENT                         4                              4
# ...         ...                       ...                            ...
# 93846     DEBIT                         5                              4
# 20961     DEBIT                         3                              4
# 41414     DEBIT                         2                              4
# 88336   PAYMENT                         6                              4
# 28386   PAYMENT                         2                              1
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...
